# %% [markdown]
# # 1. 데이터 업로드

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import cross_val_score, train_test_split, KFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv('./data/Pakistan.csv', encoding = 'unicode_escape')
print(train.shape)
train.head()
# Out:
# (51, 18)
#    S#              Politician       Day       Date     Day Type        Time  \
# 0   1         Liaqat Ali Khan   Tuesday  16-Oct-51  Working Day     Evening
# 1   2  Khan abdul Jabbar Khan    Friday   9-May-58  Working Day     Morning
# 2   3          Hayyat Sherpao    Friday   8-Feb-85  Working Day     Evening
# 3   4            Najeeb Ahmed    Friday   6-Apr-90  Working Day  After Noon
# 4   5       Azeem Ahmed Tariq  Saturday   1-May-93  Working Day     Morning
#
#          City                                       Location  \
# 0  Rawalpindi     Company Bagh (Company Gardens), Rawalpindi
# 1      Lahore   Sadullah Khan's house at 16 Aikman Road, GOR
# 2    Peshawar               Campus of University of Peshawar
# 3     Karachi                                North Nazimabad
# 4     Karachi                                 near his house
#
#   Location Category Province   Latitude  Longititude Target Category  \
# 0       Park/Ground   Punjab  33.605800    73.043700          Target
# 1         Residence   Punjab  31.482635    74.071272          Target
# 2        University      KPK  33.999533    71.425020          Target
# 3         Residence    Sindh  24.991800    66.991100          Target
# 4         Residence    Sindh  24.991800    66.991100          Target
#
#   Space (Open/Closed)                            Party Target Status  Killed  \
# 0                Open         Alll India Muslim League        Killed       1
# 1                Open  Chief Minister of West Pakistan        Killed       1
# 2                Open                             PPPP        Killed       1
# 3              Closed              Student wing of PPP        Killed       1
# 4              Closed                              MQM        Killed       1
#
#    Injured
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### 1.1) 타겟 분포 및 카테고리 변수 확인

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 18 columns):
# S#                     51 non-null int64
# Politician             51 non-null object
# Day                    51 non-null object
# Date                   51 non-null object
# Day Type               51 non-null object
# Time                   51 non-null object
# City                   51 non-null object
# Location               51 non-null object
# Location Category      48 non-null object
# Province               51 non-null object
# Latitude               51 non-null float64
# Longititude            51 non-null float64
# Target Category        51 non-null object
# Space (Open/Closed)    51 non-null object
# Party                  51 non-null object
# Target Status          51 non-null object
# Killed                 51 non-null int64
# Injured                51 non-null int64
# dtypes: float64(2), int64(3), object(13)
# memory usage: 7.3+ KB

# %%
train['Target Category'].value_counts()
# Imbalanced class는 아닌 듯 하다.
# Out:
# Suicide    27
# Target     24
# Name: Target Category, dtype: int64

# %%
object_column = train.dtypes[train.dtypes == 'object'].index.tolist()
for column in object_column:
    print("=================== " + column + " ===================")
    print(train[column].unique())
    print(train[column].value_counts())
# Out:
# =================== Politician ===================
# ['Liaqat Ali Khan' 'Khan abdul Jabbar Khan' 'Hayyat Sherpao'
#  'Najeeb Ahmed' 'Azeem Ahmed Tariq' 'Hakim Muhammad Said'
#  'Maulana Azam Tariq' 'Pervez Musharaf' 'Shaukat Aziz' 'Zil-e-Huma Usman'
#  'Aftab Ahmad Khan Sherpao' 'Political Meeting' 'Abdul Razzaq Bugti'
#  'Benazir Bhutto' 'Ahsan Iqbal' 'Miangul Asfandyar Amir Zeb'
#  'Khursheed Khan' ' Rashid Akbar Nawani' 'Hussain Ali Yousafi'
#  'Muhammed Khan Baba Jan' 'Malik Swab Khan' 'Habib Jalib Baloch'
#  '\xa0Asim Ali Kurd' 'Mir Nooruddin Mengal' '\xa0Amjad Ali Khan'
#  'Muhammad Aslam Khan Raisani' 'Salman Taseer' 'Shahbaz Bhatti'
#  'Bashir Ahmed Bilour' 'Syed Manzar Imam' '\xa0Khalid Mumtaz Kundi'
#  'Ghulam Ahmed Bilour' 'Dr Mohammad Ibrahim Jatoi\xa0' 'Syed Janan'
#  'Zahra Shahid Hussain' 'Farid Khan' 'Imran Khan Mohmand'
#  'Israr Ullah Khan Gandapur' 'Col Shuja Khanzada\xa0'
#  'Muhammad Amjad Farooq' 'Soran Singh' 'Sherin malik' 'Haroon Bilour'
#  'Akram Khan Durrani' 'Siraj Raisani']
# Political Meeting              5
# Pervez Musharaf                2
# Benazir Bhutto                 2
# Maulana Azam Tariq             1
# Muhammed Khan Baba Jan         1
# Dr Mohammad Ibrahim Jatoi      1
# Bashir Ahmed Bilour            1
#  Rashid Akbar Nawani           1
# Miangul Asfandyar Amir Zeb     1
# Ahsan Iqbal                    1
# Siraj Raisani                  1
# Mir Nooruddin Mengal           1
# Malik Swab Khan                1
# Sherin malik                   1
# Zahra Shahid Hussain           1
# Liaqat Ali Khan                1
# Soran Singh                    1
# Syed Janan                     1
# Habib Jalib Baloch             1
#  Khalid Mumtaz Kundi           1
# Muhammad Amjad Farooq          1
# Muhammad Aslam Khan Raisani    1
# Najeeb Ahmed                   1
# Salman Taseer                  1
# Abdul Razzaq Bugti             1
# Hayyat Sherpao                 1
#  Amjad Ali Khan                1
# Zil-e-Huma Usman               1
# Shahbaz Bhatti                 1
# Aftab Ahmad Khan Sherpao       1
# Haroon Bilour                  1
# Israr Ullah Khan Gandapur      1
# Col Shuja Khanzada             1
# Khan abdul Jabbar Khan         1
# Shaukat Aziz                   1
# Khursheed Khan                 1
# Farid Khan                     1
#  Asim Ali Kurd                 1
# Akram Khan Durrani             1
# Hussain Ali Yousafi            1
# Syed Manzar Imam               1
# Azeem Ahmed Tariq              1
# Imran Khan Mohmand             1
# Ghulam Ahmed Bilour            1
# Hakim Muhammad Said            1
# Name: Politician, dtype: int64
# =================== Day ===================
# ['Tuesday' 'Friday' 'Saturday' 'Monday' 'Thursday' 'Wednesday' 'Sunday']
# Friday       10
# Monday       10
# Tuesday       8
# Thursday      7
# Saturday      7
# Wednesday     7
# Sunday        2
# Name: Day, dtype: int64
# =================== Date ===================
# ['16-Oct-51' '9-May-58' '8-Feb-85' '6-Apr-90' '1-May-93' '17-Oct-98'
#  '6-Oct-03' '15-Dec-03' '25-Dec-03' '30-Jul-04' '20-Feb-07' '28-Apr-07'
#  '12-Jul-07' '27-Jul-07' '18-Oct-07' '9-Nov-07' '27-Dec-07' '28-Dec-07'
#  '9-Feb-08' '11-Feb-08' '16-Feb-08' '6-Oct-08' '26-Jan-09' '17-Dec-09'
#  '5-Apr-10' '12-Jul-10' '14-Jul-10' '9-Sep-10' '13-Oct-10' '6-Dec-10'
#  '7-Dec-10' '4-Jan-11' '2-Mar-11' '23-Dec-12' '17-Jan-13' '18-Feb-13'
#  '16-Apr-13' '1-May-13' '7-May-13' '18-May-13' '3-Jun-13' '18-Jun-13'
#  '16-Oct-13' '16-Aug-15' '19-Oct-15' '22-Apr-16' '15-Feb-17' '7-Jul-18'
#  '10-Jul-18' '13-Jul-18']
# 13-Jul-18    2
# 27-Dec-07    1
# 1-May-93     1
# 14-Jul-10    1
# 22-Apr-16    1
# 16-Aug-15    1
# 18-Jun-13    1
# 7-Dec-10     1
# 3-Jun-13     1
# 4-Jan-11     1
# 20-Feb-07    1
# 17-Dec-09    1
# 15-Feb-17    1
# 23-Dec-12    1
# 30-Jul-04    1
# 27-Jul-07    1
# 16-Feb-08    1
# 8-Feb-85     1
# 6-Dec-10     1
# 9-May-58     1
# 6-Apr-90     1
# 17-Oct-98    1
# 18-Feb-13    1
# 2-Mar-11     1
# 26-Jan-09    1
# 28-Apr-07    1
# 9-Sep-10     1
# 16-Oct-51    1
# 1-May-13     1
# 18-May-13    1
# 12-Jul-10    1
# 9-Feb-08     1
# 6-Oct-03     1
# 11-Feb-08    1
# 17-Jan-13    1
# 5-Apr-10     1
# 10-Jul-18    1
# 15-Dec-03    1
# 13-Oct-10    1
# 19-Oct-15    1
# 18-Oct-07    1
# 16-Apr-13    1
# 7-May-13     1
# 28-Dec-07    1
# 9-Nov-07     1
# 12-Jul-07    1
# 7-Jul-18     1
# 16-Oct-13    1
# 25-Dec-03    1
# 6-Oct-08     1
# Name: Date, dtype: int64
# =================== Day Type ===================
# ['Working Day' 'Holiday']
# Working Day    47
# Holiday         4
# Name: Day Type, dtype: int64
# =================== Time ===================
# ['Evening' 'Morning' 'After Noon' 'Night' 'Mid Night' 'Noon']
# Evening       23
# After Noon    19
# Morning        5
# Night          2
# Noon           1
# Mid Night      1
# Name: Time, dtype: int64
# =================== City ===================
# ['Rawalpindi' 'Lahore' 'Peshawar' 'Karachi' 'Islamabad' 'Attock'
#  'Gujranwala' 'Charsadda' 'North Waziristan' 'Quetta' 'Swat'
#  'Kuram Agency' 'Bhakkar' 'Bannu' 'Lower Dir' 'Kohat' 'KALAT'
#  'Mohmand Agency' 'Shikarpur' 'Hangu' 'Mardan' 'D.I. Khan' 'ATTOCK'
#  'Taunsa' 'Buner' 'Ghallanai Mohmand Agency']
# Quetta                      6
# Karachi                     6
# Peshawar                    6
# Rawalpindi                  4
# Islamabad                   3
# Bannu                       3
# Hangu                       2
# Charsadda                   2
# North Waziristan            2
# KALAT                       1
# Shikarpur                   1
# ATTOCK                      1
# Gujranwala                  1
# Kohat                       1
# Lower Dir                   1
# Buner                       1
# Mohmand Agency              1
# Ghallanai Mohmand Agency    1
# Lahore                      1
# Taunsa                      1
# Swat                        1
# Bhakkar                     1
# Kuram Agency                1
# Attock                      1
# Mardan                      1
# D.I. Khan                   1
# Name: City, dtype: int64
# =================== Location ===================
# ['Company Bagh (Company Gardens), Rawalpindi'
#  "\xa0Sadullah Khan's house at 16 Aikman Road, GOR"
#  'Campus of University of Peshawar' 'North Nazimabad' 'near his house'
#  'Details Missing' 'As his car drove into the capital, Islamabad'
#  'A powerful bomb went off minutes after his highly-guarded convoy crossed a bridge'
#  "Attack on Musharaf's Rally" 'Jaffar village in fateh jang'
#  'she had gone to address a political rally' 'Rally Charsadda '
#  'Political Agent Office in Miranshah'
#  '\xa0Zarghon Road 200 metres from Chief Minister\x92s House' 'PPP Rally'
#  'Political Affairs meeting' 'Liaquat Bagh Park'
#  'roadside bomb blast targeting his vehicle' 'Nakai in charsadda'
#  'Aidak village in mirali-near miranshah'
#  'PPP election office in Eidgah market of Parachinar bazar'
#  'Bhakkar Rasheed Noranni MNA house' 'UNKNOWN'
#  'Essakhel village house of Local political leader'
#  'ANP rally in Timergara '
#  'Outside the guest house of a pro-Government tribal elder-Malik Swab Khan-in Kohat District'
#  'Raily Housing Society, village of Palaseen\nNear Finance Minnister\nHouse Quetta'
#  'Market' 'Ghalani area\nAgent office '
#  'Railway level crossing sryab pattak'
#  'Kohsar Market, near his home\xa0in Sector F6,\xa0Islamabad' 'Sector i-8'
#  'Qissa Khwani Bazar' 'while traveling'
#  "Khyber Agency's Political Agent Office in Peshawar"
#  'The bomb blast took place in Yakatoot in Kotwali Abid Khan'
#  'Southern Shikarpur district of Sindh province-some 400 kilometres (250 miles) northeast of Karachi'
#  'Near Market in the town of Doaba'
#  'highly contested partial rerun of the\xa0general election'
#  'Traveling in Hangu' 'Funeral'
#  'village in Kulachi, which is located 45 kilometers from Dera Ismail Khan'
#  'Political office in Attock\x92s Shadi Khan area'
#  "At Political Party MP's office on College road Taunsa DGK."
#  'Office of political agent' "Attack on sherin malik's convoy"
#  'Yakatoot neighbourhood, Peshawar' 'Near Haved Police Station'
#  "Attack on BAP's rally"]
# near his house                                                                                        2
# UNKNOWN                                                                                               2
# Aidak village in mirali-near miranshah                                                                1
# A powerful bomb went off minutes after his highly-guarded convoy crossed a bridge                     1
# Bhakkar Rasheed Noranni MNA house                                                                     1
# Sector i-8                                                                                            1
# highly contested partial rerun of the general election                                                1
# Funeral                                                                                               1
# At Political Party MP's office on College road Taunsa DGK.                                            1
# Essakhel village house of Local political leader                                                      1
# Traveling in Hangu                                                                                    1
# Office of political agent                                                                             1
# Liaquat Bagh Park                                                                                     1
# while traveling                                                                                       1
# Southern Shikarpur district of Sindh province-some 400 kilometres (250 miles) northeast of Karachi    1
# Attack on BAP's rally                                                                                 1
# Political Agent Office in Miranshah                                                                   1
# ANP rally in Timergara                                                                                1
# Outside the guest house of a pro-Government tribal elder-Malik Swab Khan-in Kohat District            1
# Political office in Attocks Shadi Khan area                                                          1
# As his car drove into the capital, Islamabad                                                          1
# Railway level crossing sryab pattak                                                                   1
# Yakatoot neighbourhood, Peshawar                                                                      1
#  Zarghon Road 200 metres from Chief Ministers House                                                  1
# PPP election office in Eidgah market of Parachinar bazar                                              1
# Details Missing                                                                                       1
# Jaffar village in fateh jang                                                                          1
# roadside bomb blast targeting his vehicle                                                             1
# Attack on Musharaf's Rally                                                                            1
# PPP Rally                                                                                             1
# Attack on sherin malik's convoy                                                                       1
# Rally Charsadda                                                                                       1
# Market                                                                                                1
# she had gone to address a political rally                                                             1
# Qissa Khwani Bazar                                                                                    1
# Near Haved Police Station                                                                             1
# village in Kulachi, which is located 45 kilometers from Dera Ismail Khan                              1
# Kohsar Market, near his home in Sector F6, Islamabad                                                  1
# Company Bagh (Company Gardens), Rawalpindi                                                            1
#  Sadullah Khan's house at 16 Aikman Road, GOR                                                         1
# Near Market in the town of Doaba                                                                      1
# Ghalani area\nAgent office                                                                            1
# North Nazimabad                                                                                       1
# Political Affairs meeting                                                                             1
# Raily Housing Society, village of Palaseen\nNear Finance Minnister\nHouse Quetta                      1
# Campus of University of Peshawar                                                                      1
# Nakai in charsadda                                                                                    1
# The bomb blast took place in Yakatoot in Kotwali Abid Khan                                            1
# Khyber Agency's Political Agent Office in Peshawar                                                    1
# Name: Location, dtype: int64
# =================== Location Category ===================
# ['Park/Ground' 'Residence' 'University' 'Details Missing' 'Road'
#  'Government' 'Religious' 'UNKNOWN' 'Hotel' 'Market' 'Transport' nan
#  'Office Building' 'Mobile' 'Funeral']
# Residence          14
# Road               11
# Park/Ground         5
# Market              4
# Government          4
# UNKNOWN             2
# University          1
# Details Missing     1
# Funeral             1
# Office Building     1
# Religious           1
# Mobile              1
# Transport           1
# Hotel               1
# Name: Location Category, dtype: int64
# =================== Province ===================
# ['Punjab' 'KPK' 'Sindh' 'Capital' 'FATA' 'Balochistan' 'Fata']
# KPK            19
# Punjab         10
# Sindh           7
# Balochistan     7
# FATA            4
# Capital         3
# Fata            1
# Name: Province, dtype: int64
# =================== Target Category ===================
# ['Target' 'Suicide']
# Suicide    27
# Target     24
# Name: Target Category, dtype: int64
# =================== Space (Open/Closed) ===================
# ['Open' 'Closed']
# Open      36
# Closed    15
# Name: Space (Open/Closed), dtype: int64
# =================== Party ===================
# ['Alll India Muslim League' 'Chief Minister of West Pakistan' 'PPPP'
#  'Student wing of PPP' 'MQM' 'Independent' 'Millat-i-Islamia'
#  'All Pakistan Muslim League' 'PMLQ' 'Ministor' 'ANP'
#  'Local Political Leader' 'Baloch Student Organizaion' 'PMLN'
#  'Hazara Democratic Party\xa0(HDP)' 'Pro-Government tribal elder'
#  'Baloch Nationalist' 'BNP' 'mqm' 'Assistant Political Agent'
#  "National People's Party" 'JUIF' 'PTI' 'Ministor of Miniroties' 'MMA'
#  'BAP']
# PPPP                               8
# ANP                                7
# PMLN                               5
# Local Political Leader             4
# PTI                                3
# Independent                        2
# JUIF                               2
# All Pakistan Muslim League         2
# MQM                                1
# Ministor of Miniroties             1
# Pro-Government tribal elder        1
# BNP                                1
# mqm                                1
# PMLQ                               1
# Assistant Political Agent          1
# Chief Minister of West Pakistan    1
# Baloch Student Organizaion         1
# BAP                                1
# National People's Party            1
# Student wing of PPP                1
# Hazara Democratic Party (HDP)      1
# Alll India Muslim League           1
# MMA                                1
# Baloch Nationalist                 1
# Ministor                           1
# Millat-i-Islamia                   1
# Name: Party, dtype: int64
# =================== Target Status ===================
# ['Killed' 'Escaped']
# Killed     31
# Escaped    20
# Name: Target Status, dtype: int64

# %% [markdown]
# 데이터 확인을 하였으니, 필요없는 변수 빼기
#
# 1. Day 요일 별
# 2. Date -> 특정 기간에서 빼기
# 3. Day Type -> Label encoding
# 4. Time = Label encoding
# 5. City = One-hot
# 6. Location  제거
# 7. Location Category 대신 넣기
# 8. Province
# 9. Space (Open/Closed) : label
# 10. Party = label
# 11. Target Status = label
#
#
# #### Target Category = target 값

# %% [markdown]
# ### 2. 결측값 확인

# %%
train.isnull().sum() 
# 결측값 최빈값으로 대체
train = train.fillna('Residence')

# %% [markdown]
# ### 3. 레이블 인코딩

# %%
train.drop(['S#','Politician', 'Latitude', 'Longititude', 'Date','Location'], axis = 1, inplace = True)
object_columns = train.dtypes[train.dtypes == 'object'].index.tolist()

# LabelEncoder() 와 같은 pandas의 factorize
for column in object_columns:
    train[column] = pd.factorize(train[column])[0]

# %% [markdown]
# # 3. 모델링

# %%
# 레이블 인코딩용
Train = train.drop('Target Category', axis = 1, inplace = False)
target = train['Target Category']

print(Train.shape , target.shape)
# Out:
# (51, 11) (51,)

# %% [markdown]
# ### 3.1 RandomForest

# %%
rf_clf = RandomForestClassifier(n_jobs = -1,random_state = 2015)                               
scores = cross_val_score(rf_clf, Train , target , scoring = 'f1', cv=10)

for iter_count, f1_score in enumerate(scores):
    print("fold {0} F1 score: {1:.4f}".format(iter_count+1, f1_score))

print("Total (Average) F1 score: {0:.4f}".format(np.mean(scores)))
# Out:
# fold 1 F1 score: 1.0000
# fold 2 F1 score: 1.0000
# fold 3 F1 score: 0.8571
# fold 4 F1 score: 1.0000
# fold 5 F1 score: 1.0000
# fold 6 F1 score: 1.0000
# fold 7 F1 score: 1.0000
# fold 8 F1 score: 1.0000
# fold 9 F1 score: 0.0000
# fold 10 F1 score: 0.6667
# Total (Average) F1 score: 0.8524

# %%
rf_clf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators='warn',
#                        n_jobs=-1, oob_score=False, random_state=2015, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ### 3.2 최적화

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Train, target, test_size=0.2, random_state=2015)

params = { 'n_estimators' : [80, 100, 120],
           'max_depth' : [2, 3, 4, 5],
           'min_samples_leaf' : [1, 2, 3],
           'min_samples_split' : [2, 3, 4]
            }

# RandomForestClassifier 객체 생성 후 GridSearchCV 수행하였습니다.
rf_clf = RandomForestClassifier(random_state = 2015, n_jobs = -1)
grid_cv = GridSearchCV(rf_clf, param_grid = params, cv = 3, scoring='f1', n_jobs = -1)
grid_cv.fit(X_train, Y_train)

print('최적 하이퍼 파라미터: ', grid_cv.best_params_)
print('최고 예측 F1 score: {:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:  {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 120}
# 최고 예측 F1 score: 0.9594
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %% [markdown]
# ## 4. Measures

# %%
rf_clf = RandomForestClassifier(n_estimators = 80,
                                max_depth = 2,
                                min_samples_leaf = 1,
                                min_samples_split = 2,
                                 n_jobs = -1,
                                random_state = 2015)
                                
scores = cross_val_score(rf_clf, Train , target , scoring = 'f1', cv=10)

for iter_count, f1_score in enumerate(scores):
    print("fold {0} F1 score: {1:.4f}".format(iter_count+1, f1_score))

print("Total (Average) F1 score: {0:.4f}".format(np.mean(scores)))
# Out:
# fold 1 F1 score: 1.0000
# fold 2 F1 score: 1.0000
# fold 3 F1 score: 1.0000
# fold 4 F1 score: 0.8000
# fold 5 F1 score: 0.8000
# fold 6 F1 score: 1.0000
# fold 7 F1 score: 1.0000
# fold 8 F1 score: 1.0000
# fold 9 F1 score: 0.8000
# fold 10 F1 score: 0.6667
# Total (Average) F1 score: 0.9067
